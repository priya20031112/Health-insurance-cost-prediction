# %% [markdown]
# <a href="https://colab.research.google.com/github/AsmaShaik28/Health-insurance-cost-prediction-/blob/main/Health_insurance_cost_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/insurance.csv')

# %%
data.sample(5)
# Out:
#      index  age     sex     bmi  children smoker     region      charges
# 660    660   37    male  46.530         3     no  southeast   6435.62370
# 116    116   58    male  49.060         0     no  southeast  11381.32540
# 965    965   35    male  27.100         1     no  southwest   4746.34400
# 833    833   58    male  34.390         0     no  northwest  11743.93410
# 882    882   21  female  22.135         0     no  northeast   2585.85065

# %%
data.head(8)
# Out:
#    index  age     sex     bmi  children smoker     region      charges
# 0      0   19  female  27.900         0    yes  southwest  16884.92400
# 1      1   18    male  33.770         1     no  southeast   1725.55230
# 2      2   28    male  33.000         3     no  southeast   4449.46200
# 3      3   33    male  22.705         0     no  northwest  21984.47061
# 4      4   32    male  28.880         0     no  northwest   3866.85520
# 5      5   31  female  25.740         0     no  southeast   3756.62160
# 6      6   46  female  33.440         1     no  southeast   8240.58960
# 7      7   37  female  27.740         3     no  northwest   7281.50560

# %%
data.describe()
# Out:
#              index          age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000  1338.000000   1338.000000
# mean    668.500000    39.207025    30.663397     1.094918  13270.422265
# std     386.391641    14.049960     6.098187     1.205493  12110.011237
# min       0.000000    18.000000    15.960000     0.000000   1121.873900
# 25%     334.250000    27.000000    26.296250     0.000000   4740.287150
# 50%     668.500000    39.000000    30.400000     1.000000   9382.033000
# 75%    1002.750000    51.000000    34.693750     2.000000  16639.912515
# max    1337.000000    64.000000    53.130000     5.000000  63770.428010

# %%
data.tail()
# Out:
#       index  age     sex    bmi  children smoker     region     charges
# 1333   1333   50    male  30.97         3     no  northwest  10600.5483
# 1334   1334   18  female  31.92         0     no  northeast   2205.9808
# 1335   1335   18  female  36.85         0     no  southeast   1629.8335
# 1336   1336   21  female  25.80         0     no  southwest   2007.9450
# 1337   1337   61  female  29.07         0    yes  northwest  29141.3603

# %%
data.shape
# Out:
# (1338, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     1338 non-null   int64
#  1   age       1338 non-null   int64
#  2   sex       1338 non-null   object
#  3   bmi       1338 non-null   float64
#  4   children  1338 non-null   int64
#  5   smoker    1338 non-null   object
#  6   region    1338 non-null   object
#  7   charges   1338 non-null   float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 83.8+ KB

# %%
data.shape
print("Number of rows",data.shape[0])
print("Number of columns",data.shape[1])
# Out:
# Number of rows 1338
# Number of columns 8

# %%
data.isnull().sum()
# Out:
# index       0
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#               index          age   sex          bmi     children smoker  \
# count   1338.000000  1338.000000  1338  1338.000000  1338.000000   1338
# unique          NaN          NaN     2          NaN          NaN      2
# top             NaN          NaN  male          NaN          NaN     no
# freq            NaN          NaN   676          NaN          NaN   1064
# mean     668.500000    39.207025   NaN    30.663397     1.094918    NaN
# std      386.391641    14.049960   NaN     6.098187     1.205493    NaN
# min        0.000000    18.000000   NaN    15.960000     0.000000    NaN
# 25%      334.250000    27.000000   NaN    26.296250     0.000000    NaN
# 50%      668.500000    39.000000   NaN    30.400000     1.000000    NaN
# 75%     1002.750000    51.000000   NaN    34.693750     2.000000    NaN
# max     1337.000000    64.000000   NaN    53.130000     5.000000    NaN
#
#            region       charges
# count        1338   1338.000000
# unique          4           NaN
# ...

# %%
data["sex"].unique()   #converting columns from strings[sex,smoker,region] to numerical values
# Out:
# array(['female', 'male'], dtype=object)

# %%
data['sex']=data['sex'].map({'female':1,'male':0})

# %%
data['smoker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
data['smoker']=data['smoker'].map({'yes':1,'no':0})

# %%
data['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data['region']=data['region'].map({'southwest':4, 'southeast':3, 'northwest':2, 'northeast':1})

# %%
data.head()
# Out:
#    index  age  sex     bmi  children  smoker  region      charges
# 0      0   19    1  27.900         0       1       4  16884.92400
# 1      1   18    0  33.770         1       0       3   1725.55230
# 2      2   28    0  33.000         3       0       3   4449.46200
# 3      3   33    0  22.705         0       0       2  21984.47061
# 4      4   32    0  28.880         0       0       2   3866.85520

# %%
data.drop(1)
# Out:
#       index  age  sex     bmi  children  smoker  region      charges
# 0         0   19    1  27.900         0       1       4  16884.92400
# 2         2   28    0  33.000         3       0       3   4449.46200
# 3         3   33    0  22.705         0       0       2  21984.47061
# 4         4   32    0  28.880         0       0       2   3866.85520
# 5         5   31    1  25.740         0       0       3   3756.62160
# ...     ...  ...  ...     ...       ...     ...     ...          ...
# 1333   1333   50    0  30.970         3       0       2  10600.54830
# 1334   1334   18    1  31.920         0       0       1   2205.98080
# 1335   1335   18    1  36.850         0       0       3   1629.83350
# 1336   1336   21    1  25.800         0       0       4   2007.94500
# 1337   1337   61    1  29.070         0       1       2  29141.36030
#
# [1337 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['index', 'age', 'sex', 'bmi', 'children', 'smoker', 'region',
#        'charges'],
#       dtype='object')

# %%
X=data.drop(['charges'],axis=1)
X
# Out:
#       index  age  sex     bmi  children  smoker  region
# 0         0   19    1  27.900         0       1       4
# 1         1   18    0  33.770         1       0       3
# 2         2   28    0  33.000         3       0       3
# 3         3   33    0  22.705         0       0       2
# 4         4   32    0  28.880         0       0       2
# ...     ...  ...  ...     ...       ...     ...     ...
# 1333   1333   50    0  30.970         3       0       2
# 1334   1334   18    1  31.920         0       0       1
# 1335   1335   18    1  36.850         0       0       3
# 1336   1336   21    1  25.800         0       0       4
# 1337   1337   61    1  29.070         0       1       2
#
# [1338 rows x 7 columns]

# %%
y=data['charges']
y
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=20)

# %%
X_train
# Out:
#       index  age  sex    bmi  children  smoker  region
# 1204   1204   18    1  27.28         3       1       3
# 829     829   39    0  21.85         1       0       2
# 1077   1077   21    0  26.03         0       0       1
# 416     416   52    0  34.10         0       0       3
# 1295   1295   20    0  22.00         1       0       4
# ...     ...  ...  ...    ...       ...     ...     ...
# 1242   1242   22    1  21.28         3       0       2
# 924     924   43    0  23.20         0       0       4
# 1247   1247   33    0  29.40         4       0       4
# 271     271   50    0  34.20         2       1       4
# 474     474   54    0  25.10         3       1       4
#
# [1070 rows x 7 columns]

# %%
y_train
# Out:
# 1204    18223.4512
# 829      6117.4945
# 1077     2102.2647
# 416      9140.9510
# 1295     1964.7800
#            ...
# 1242     4296.2712
# 924      6250.4350
# 1247     6059.1730
# 271     42856.8380
# 474     25382.2970
# Name: charges, Length: 1070, dtype: float64

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1070, 7)
# (1070,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (268, 7)
# (268,)

# %%
#import the models
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
#model training
lr=LinearRegression()
lr.fit(X_train,y_train)
svm=SVR()
svm.fit(X_train,y_train)
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
gr=GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
#model training
lr=LinearRegression()
lr.fit(X_train,y_train)
svm=SVR()
svm.fit(X_train,y_train)
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
gr=GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
X=data.drop(['charges'],axis=1)
y=data['charges']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# These cells were moved from earlier in the notebook to ensure they are run after the data preprocessing steps.
X=data.drop(['charges'],axis=1)
y=data['charges']
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
y_pred1=lr.predict(X_test)
y_pred2=svm.predict(X_test)
y_pred3=rf.predict(X_test)
y_pred4=gr.predict(X_test)

df1=pd.DataFrame({'Actual':y_test,'Lr':y_pred1,'svm':y_pred2,'rf':y_pred3,'gr':y_pred4})
df1
# Out:
#            Actual            Lr          svm            rf            gr
# 17     2395.17155   1840.577764  9155.828154   3356.248846   3578.836770
# 1091  11286.53870  12212.877874  9155.806636  11280.858094  12422.115406
# 273    9617.66245  10391.390035  9158.484050  10524.772796  10644.471972
# 270    1719.43630   2433.711653  9157.840166   1771.362514   3687.507851
# 874    8891.13950   8258.915133  9157.990144   9615.596114   8923.987110
# ...           ...           ...          ...           ...           ...
# 232    1727.78500  -2004.884624  9157.551196   2548.354121   2204.540201
# 323   11566.30055  16164.127433  9159.014157  11659.136603  12904.557188
# 1337  29141.36030  36882.016714  9153.317005  28829.855315  29260.043964
# 1066   8978.18510  13314.686816  9155.986496   9094.212543  10513.391076
# 966   23967.38305  33837.369005  9157.176314  24191.993398  24793.129820
#
# [268 rows x 5 columns]

# %%
df1.head()
# Out:
#            Actual            Lr          svm            rf            gr
# 17     2395.17155   1840.577764  9155.828154   3356.248846   3578.836770
# 1091  11286.53870  12212.877874  9155.806636  11280.858094  12422.115406
# 273    9617.66245  10391.390035  9158.484050  10524.772796  10644.471972
# 270    1719.43630   2433.711653  9157.840166   1771.362514   3687.507851
# 874    8891.13950   8258.915133  9157.990144   9615.596114   8923.987110

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(221)
plt.plot(df1['Actual'].iloc[0:10],label='Actual')
plt.plot(df1['Lr'].iloc[0:10],label='Lr')
plt.legend()
plt.subplot(222)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['svm'].iloc[0:11],label='svm')
plt.legend()
plt.subplot(223)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['rf'].iloc[0:11],label='rf')
plt.legend()
plt.subplot(224)
plt.plot(df1['Actual'].iloc[0:11],label='Actual')
plt.plot(df1['gr'].iloc[0:11],label='gr')
plt.legend()
plt.show()

# %%
#Evaluation: by r2(to measure goodness)
#import required libraries
from sklearn import metrics
score1=metrics.r2_score(y_test,y_pred1)    #lr
score2=metrics.r2_score(y_test,y_pred2)    #svm
score3=metrics.r2_score(y_test,y_pred3)    #rf
score4=metrics.r2_score(y_test,y_pred4)    #gb
print(score1,score2,score3,score4)
# Out:
# 0.7450284592988596 -0.09085761314452911 0.9688606487069963 0.9050405330515552

# %%
data={'index':0,
      'age':22,
      'sex':1,
      'bmi':40.20,
      'children':2,
      'smoker':1,'region':2,}
df=pd.DataFrame(data,index=[0])
df = df[X_train.columns]
df
# Out:
#    index  age  sex   bmi  children  smoker  region
# 0      0   22    1  40.2         2       1       2

# %%
new_pred1=gr.predict(df)
print("prediction cost for new customer is=",new_pred1)
# Out:
# prediction cost for new customer is= [39208.35448031]

# %%
gr=GradientBoostingRegressor()
gr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
# Evaluation: using other metrics
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

mae1 = mean_absolute_error(y_test, y_pred1)
mse1 = mean_squared_error(y_test, y_pred1)
rmse1 = np.sqrt(mse1)

mae2 = mean_absolute_error(y_test, y_pred2)
mse2 = mean_squared_error(y_test, y_pred2)
rmse2 = np.sqrt(mse2)

mae3 = mean_absolute_error(y_test, y_pred3)
mse3 = mean_squared_error(y_test, y_pred3)
rmse3 = np.sqrt(mse3)

mae4 = mean_absolute_error(y_test, y_pred4)
mse4 = mean_squared_error(y_test, y_pred4)
rmse4 = np.sqrt(mse4)

print(f"Linear Regression MAE: {mae1}, MSE: {mse1}, RMSE: {rmse1}")
print(f"SVM MAE: {mae2}, MSE: {mse2}, RMSE: {rmse2}")
print(f"Random Forest MAE: {mae3}, MSE: {mse3}, RMSE: {rmse3}")
print(f"Gradient Boosting MAE: {mae4}, MSE: {mse4}, RMSE: {rmse4}")
# Out:
# Linear Regression MAE: 4326.8308839804495, MSE: 38291820.21450094, RMSE: 6188.038478750835
# SVM MAE: 8518.186585985399, MSE: 163825827.33463123, RMSE: 12799.44636828606
# Random Forest MAE: 1190.580085095897, MSE: 4676531.498491876, RMSE: 2162.5289589949716
# Gradient Boosting MAE: 2055.1047482514355, MSE: 14261085.084459508, RMSE: 3776.385187511929

# %%
# Create a new customer's data
new_customer_data = {
    'index': 0,  # You might want to assign a unique index or drop this column if not needed for prediction
    'age': 30,
    'sex': 0, # 0 for male, 1 for female (based on your mapping)
    'bmi': 25.0,
    'children': 1,
    'smoker': 0, # 0 for no, 1 for yes (based on your mapping)
    'region': 1 # 1 for northeast, 2 for northwest, 3 for southeast, 4 for southwest (based on your mapping)
}

new_customer_df = pd.DataFrame(new_customer_data, index=[0])

# Ensure the new data has the same columns as the training data, excluding the target variable
new_customer_df = new_customer_df[X_train.columns]

# Predict the charges using the Random Forest model
predicted_charge_rf = rf.predict(new_customer_df)

print(f"Predicted insurance charge for the new customer using Random Forest: {predicted_charge_rf[0]:.2f}")
# Out:
# Predicted insurance charge for the new customer using Random Forest: 9473.53
